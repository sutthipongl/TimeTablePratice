# %%
import random
from timeit import default_timer as timer

# INIT
timetable = 6
questions = []

#REWARD
reward = 3
bonus = 5
totalreward = 0


completed = 1

start = timer()
while (completed<=12) :
  
    IsCorrect=False
    temp = random.randint(1, 12)
    
    while (temp in questions) :
        temp = random.randint(1, 12)

    questions.append(temp)
    
    while (not IsCorrect) :
        print("Question",completed, " : " , timetable, "times " , questions[completed-1])
        ans = input("ANSWER : ")
        
        if (ans.isdigit() and int(ans) == timetable*questions[completed-1]) :
            print("Correct !")
            totalreward += reward
            IsCorrect = True
        else :
            tryagain = input("Opps wrong ! Do you want to try again (Y/N)? ")
            if (tryagain == 'Y' or tryagain == 'y') :
                    IsCorrect = False
            else :
                    IsCorrect = True
            
    
    completed+=1

    end = timer()
print("Your reward is ",totalreward)
timespend = end - start
print("You took ", timespend , " sec ")

if ( timespend < 5*60) :
    totalreward += bonus
    print("Congratulation !! TIME BONUS is COMING !!!")
    print("YOU GOT ",totalreward , "min today")
else :
    print("Sorry , no time bonus today but keep your chin up !!! try again !!")
# Out:
# Question 1  :  6 times  5
# ANSWER : 30
# Correct !
# Question 2  :  6 times  4
# ANSWER : 24
# Correct !
# Question 3  :  6 times  9
# ANSWER : 54
# Correct !
# Question 4  :  6 times  1
# ANSWER : 6
# Correct !
# Question 5  :  6 times  12
# ANSWER : 72
# Correct !
# Question 6  :  6 times  11
# ANSWER : 66
# Correct !
# Question 7  :  6 times  7
# ANSWER : 42
# Correct !
# Question 8  :  6 times  8
# ANSWER : 48
# Correct !
# Question 9  :  6 times  10
# ANSWER : 60
# Correct !
# Question 10  :  6 times  2
# ANSWER : 12
# Correct !
# Question 11  :  6 times  6
# ANSWER : 36
# Correct !
# Question 12  :  6 times  3
# ANSWER : 18
# Correct !
# Your reward is  36
# You took  277.4118903130293  sec
# Congratulation !! TIME BONUS is COMING !!!
# YOU GOT  41 min today
